# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm

# %%
pd.set_option("display.max_columns", 500)

# %%
#Listing currently existing tables in the database
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        SELECT name
        FROM sqlite_master 
        WHERE type ='table' 
        AND name NOT LIKE 'sqlite_%';
        """ 

    test_df = pd.read_sql(query, db)

display(test_df)
# Out:
#                    name
# 0              taxonomy
# 1           hop_teaming
# 2               npidata
# 3  filtered_hop_teaming

# %%
# Test to confirm the tables loaded.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT COUNT(*) AS count_all
    FROM filtered_hop_teaming;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#    count_all
# 0     132000

# %%
# Find NPIs with largest number of referrals
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT SUM(transaction_count) AS total_referrals, to_npi, n.provider_org_name
    FROM filtered_hop_teaming AS f
    JOIN npidata AS n
    ON f.to_npi = n.npi
    GROUP BY to_npi
    ORDER BY total_referrals DESC
    LIMIT 20;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#     total_referrals      to_npi                       provider_org_name
# 0           1113176  1104202761    VANDERBILT UNIVERSITY MEDICAL CENTER
# 1            876679  1093741464         ADVANCED DIAGNOSTIC IMAGING, PC
# 2            849974  1437194669           SAINT THOMAS MEDICAL PARTNERS
# 3            764787  1396882205    VANDERBILT UNIVERSITY MEDICAL CENTER
# 4            711886  1861478489                   RADIOLOGY ALLIANCE PC
# 5            642771  1003863580            ASSOCIATED PATHOLOGISTS, LLC
# 6            409468  1245393057                    CENTENNIAL HEART LLC
# 7            382116  1235186800                     PATHGROUP LABS, LLC
# 8            345431  1215932413            ANESTHESIA MEDICAL GROUP, PC
# 9            311019  1811955917                 TENNESSEE ONCOLOGY PLLC
# 10           257331  1023055126  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 11           256085  1548284060          HERITAGE MEDICAL ASSOCIATES PC
# 12           242902  1700878360               NEPHROLOGY ASSOCIATES, PC
# 13           232875  1538153937       TENNESSEE ORTHOPAEDIC ALLIANCE PA
# 14           196393  1205886264       MAURY REGIONAL MEDICAL GROUP, INC
# 15           195878  1629025648              SAINT THOMAS WEST HOSPITAL
# 16           182728  1467460725     SOUTHERN RADIOLOGY ASSOCIATES, PLLC
# 17           179215  1043297542                   UROLOGY ASSOCIATES PC
# 18           171866  1770667289            MIDDLE TENNESSEE IMAGING LLC
# 19           163621  1861479545                 MAURY REGIONAL HOSPITAL

# %%
# Find competitor hosptitals with the largest number of total referrals.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT SUM(transaction_count) AS total_referrals, to_npi, n.provider_org_name, t.classification
    FROM filtered_hop_teaming AS f
    JOIN npidata AS n
    ON f.to_npi = n.npi
    JOIN taxonomy AS t
    USING(taxonomy_code)
    GROUP BY to_npi, provider_org_name
    HAVING provider_org_name NOT LIKE '%VANDERBILT%'
    ORDER BY total_referrals DESC
    LIMIT 50;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#     total_referrals      to_npi  \
# 0            876679  1093741464
# 1            849974  1437194669
# 2            711886  1861478489
# 3            642771  1003863580
# 4            409468  1245393057
# 5            382116  1235186800
# 6            345431  1215932413
# 7            311019  1811955917
# 8            257331  1023055126
# 9            256085  1548284060
# 10           242902  1700878360
# 11           232875  1538153937
# 12           196393  1205886264
# 13           195878  1629025648
# 14           182728  1467460725
# 15           179215  1043297542
# 16           171866  1770667289
# 17           163621  1861479545
# 18           162365  1487604609
# 19           142892  1912953381
# 20           138803  1679560023
# 21           132207  1265445506
# 22           132094  1780778969
# 23           128091  1104854124
# 24           122827  1164590386
# 25           112191  1982650024
# 26           110324  1538400098
# 27           106444  1194758979
# 28           105907  1295780476
# 29           105370  1316043524
# 30           101704  1417983099
# 31            95866  1568464873
# 32            87992  1861433633
# 33            86664  1962417444
# 34            84995  1447571658
# 35            83509  1134131915
# 36            82178  1538114434
# 37            74834  1811988777
# 38            74170  1497828321
# 39            68209  1124420880
# 40            64423  1982013728
# 41            61415  1891995163
# 42            60161  1073585774
# 43            60109  1215008032
# 44            59679  1366872053
# 45            58511  1922057181
# 46            57590  1871530832
# 47            54832  1972577351
# 48            53678  1497827364
# 49            51857  1720032345
#
#                                     provider_org_name  \
# 0                     ADVANCED DIAGNOSTIC IMAGING, PC
# 1                       SAINT THOMAS MEDICAL PARTNERS
# 2                               RADIOLOGY ALLIANCE PC
# 3                        ASSOCIATED PATHOLOGISTS, LLC
# 4                                CENTENNIAL HEART LLC
# 5                                 PATHGROUP LABS, LLC
# 6                        ANESTHESIA MEDICAL GROUP, PC
# 7                             TENNESSEE ONCOLOGY PLLC
# 8              HCA HEALTH SERVICES OF TENNESSEE, INC.
# 9                      HERITAGE MEDICAL ASSOCIATES PC
# 10                          NEPHROLOGY ASSOCIATES, PC
# 11                  TENNESSEE ORTHOPAEDIC ALLIANCE PA
# 12                  MAURY REGIONAL MEDICAL GROUP, INC
# 13                         SAINT THOMAS WEST HOSPITAL
# 14                SOUTHERN RADIOLOGY ASSOCIATES, PLLC
# 15                              UROLOGY ASSOCIATES PC
# 16                       MIDDLE TENNESSEE IMAGING LLC
# 17                            MAURY REGIONAL HOSPITAL
# 18                        MURFREESBORO MEDICAL CLINIC
# 19                CARDIOVASCULAR ANESTHESIOLOGISTS PC
# 20      COLUMBIA MEDICAL GROUP - THE FRIST CLINIC INC
# 21                WILLIAMSON COUNTY HOSPITAL DISTRICT
# 22                         SAINT THOMAS WEST HOSPITAL
# 23                ANESTHESIA SERVICES ASSOCIATES PLLC
# 24                   SAINT THOMAS RUTHERFORD HOSPITAL
# 25             HCA HEALTH SERVICES OF TENNESSEE, INC.
# 26                                      LAB PLUS, LLC
# 27           MIDDLE TENNESSEE EMERGENCY PHYSICIANS PC
# 28                  HTI MEMORIAL HOSPITAL CORPORATION
# 29  MURFREESBORO RADIOLOGY & NUCLEAR MED CONSLT, INC.
# 30                           THE SURGICAL CLINIC PLLC
# 31                      DICKSON MEDICAL ASSOCIATES PC
# 32                               SUMNER RADIOLOGY, PC
# 33                                   AGILITAS USA INC
# 34                 SUMNER REGIONAL MEDICAL CENTER LLC
# 35  METROPOLITAN GOVERNMENT OF NASHVILLE AND DAVID...
# 36                HENDERSONVILLE HOSPITAL CORPORATION
# 37                  FIRST CALL AMBULANCE SERVICE, LLC
# 38                                TENNESSEE RETINA PC
# 39                WELLNESS SOLUTIONS GERIATRICS, PLLC
# 40                   MARATHON INPATIENT SERVICES PLLC
# 41                                            ACLA PC
# 42                 PATHOLOGY ASSOCIATES OF ST. THOMAS
# 43                 MIDDLE TENNESSEE PULMONARY ASSOCIA
# 44                      WILLIAMSON MEDICAL GROUP, LLC
# 45                         MID-TENNESSEE BONE & JOINT
# 46             CENTRAL TENNESSEE HOSPITAL CORPORATION
# 47         PREMIER ORTHOPAEDICS & SPORTS MEDICINE PLC
# 48                       MIDDLE TENNESSEE HOSPITALIST
# 49             HCA HEALTH SERVICES OF TENNESSEE, INC.
#
#                  classification
# 0                     Radiology
# 1             Internal Medicine
# 2                     Radiology
# 3                     Pathology
# 4                    Specialist
# 5   Clinical Medical Laboratory
# 6                Anesthesiology
# 7             Internal Medicine
# 8   General Acute Care Hospital
# 9             Internal Medicine
# 10            Internal Medicine
# 11          Orthopaedic Surgery
# 12              Family Medicine
# 13  General Acute Care Hospital
# 14                    Radiology
# 15                      Urology
# 16                    Radiology
# 17  General Acute Care Hospital
# 18                   Specialist
# 19               Anesthesiology
# 20            Internal Medicine
# 21  General Acute Care Hospital
# 22  General Acute Care Hospital
# 23               Anesthesiology
# 24  General Acute Care Hospital
# 25  General Acute Care Hospital
# 26  Clinical Medical Laboratory
# 27           Emergency Medicine
# 28  General Acute Care Hospital
# 29                    Radiology
# 30                      Surgery
# 31              Family Medicine
# 32                    Radiology
# 33                Clinic/Center
# 34  General Acute Care Hospital
# 35                    Ambulance
# 36  General Acute Care Hospital
# 37                    Ambulance
# 38                Ophthalmology
# 39           Nurse Practitioner
# 40            Internal Medicine
# 41                    Pathology
# 42                    Pathology
# 43                Clinic/Center
# 44            Internal Medicine
# 45          Orthopaedic Surgery
# 46  General Acute Care Hospital
# 47          Orthopaedic Surgery
# 48                  Hospitalist
# 49  General Acute Care Hospital

# %%
# Find competitor hosptitals with the largest number of total referrals.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT classification, SUM(transaction_count)
    FROM filtered_hop_teaming AS f
    JOIN npidata AS n
    ON f.to_npi = n.npi
    JOIN taxonomy AS t
    USING(taxonomy_code)
    WHERE provider_org_name LIKE '%VANDERBILT%'
    GROUP BY classification
    ORDER BY SUM(transaction_count) DESC;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#                 classification  SUM(transaction_count)
# 0            Internal Medicine                 1140517
# 1  General Acute Care Hospital                  828307
# 2                    Radiology                   18882
# 3                     Pharmacy                   16718
# 4      Rehabilitation Hospital                    6305
# 5                  Home Health                    4812
# 6                Clinic/Center                    3904
# 7          Rehabilitation Unit                     683
# 8             Psychiatric Unit                     559

# %%
# Find addresses of all Vanderbilt locations
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM npidata
    WHERE provider_org_name LIKE '%VANDERBILT%'
    GROUP BY provider_business_address_1
        , provider_business_city
        , provider_business_state
        , provider_business_zip5
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#            npi entity_type_code                         provider_org_name  \
# 0   1104166313                2  VANDERBILT MAURY RADIATION ONCOLOGY, LLC
# 1   1316974231                2                     VANDERBILT UNIVERSITY
# 2   1013215086                2                     VANDERBILT UNIVERSITY
# 3   1467599563                2                     VANDERBILT UNIVERSITY
# 4   1891951513                2                  CONCENTRA VANDERBILT LLC
# ..         ...              ...                                       ...
# 66  1972749406                2          VANDERBILT ORTHOPAEDIC INSTITUTE
# 67  1992770119                2                 VANDERBILT MEDICAL CENTER
# 68  1508132242                2      VANDERBILT UNIVERSITY MEDICAL CENTER
# 69  1245485200                2      VANDERBILT UNIVERSITY MEDICAL CENTER
# 70  1124017959                2      VANDERBILT UNIVERSITY MEDICAL SCHOOL
#
#    provider_last_name provider_first_name provider_middle_name  \
# 0                None                None                 None
# 1                None                None                 None
# 2                None                None                 None
# 3                None                None                 None
# 4                None                None                 None
# ..                ...                 ...                  ...
# 66               None                None                 None
# 67               None                None                 None
# 68               None                None                 None
# 69               None                None                 None
# 70               None                None                 None
#
#    provider_name_prefix provider_name_suffix provider_credential  \
# 0                  None                 None                None
# 1                  None                 None                None
# 2                  None                 None                None
# 3                  None                 None                None
# 4                  None                 None                None
# ..                  ...                  ...                 ...
# 66                 None                 None                None
# 67                 None                 None                None
# 68                 None                 None                None
# 69                 None                 None                None
# 70                 None                 None                None
#
#                           provider_business_address_1  \
# 0                                   1003 RESERVE BLVD
# 1                                     1161 21ST AVE S
# 2                             1161 21ST AVE S RM 1815
# 3                             1161 21ST AVENUE, SOUTH
# 4                               1203-A MEMORIAL BLVD.
# ..                                                ...
# 66                    MEDICAL CENTER EAST SOUTH TOWER
# 67                        S-3414 MEDICAL CENTER NORTH
# 68                      VANDERBILT CHILDRENS HOSPITAL
# 69                        VANDERBILT MEDICAL GENETICS
# 70  VANDERBILT UNIVERSITY DIVISION OF MEDICAL GENE...
#
#         provider_business_address_2 provider_business_city  \
# 0                         SUITE 120            SPRING HILL
# 1   ROOM 1815 THE VANDERBILT CLINIC              NASHVILLE
# 2             THE VANDERBILT CLINIC              NASHVILLE
# 3       S-7400 MEDICAL CENTER NORTH              NASHVILLE
# 4                              None           MURFREESBORO
# ..                              ...                    ...
# 66                       SUITE 3200              NASHVILLE
# 67       C/O INTERNAL MEDICINE DEPT              NASHVILLE
# 68   2200 CHILDREN'S WAY, DOT 11126              NASHVILLE
# 69                      DD-2205 MCN              NASHVILLE
# 70                      DD 2205 MCN              NASHVILLE
#
#    provider_business_state provider_business_zip taxonomy_code  \
# 0                       TN                 37174    261QX0203X
# 1                       TN             372320001    3336S0011X
# 2                       TN             372320001    3336C0003X
# 3                       TN                 37232    314000000X
# 4                       TN                 37129    261QH0100X
# ..                     ...                   ...           ...
# 66                      TN             372320001    283X00000X
# 67                      TN             372320001    282N00000X
# 68                      TN             372320001    261Q00000X
# 69                      TN             372320001    170300000X
# 70                      TN             372320001    170300000X
#
#    provider_business_zip5
# 0                   37174
# 1                   37232
# 2                   37232
# 3                   37232
# 4                   37129
# ..                    ...
# 66                  37232
# 67                  37232
# 68                  37232
# 69                  37232
# 70                  37232
#
# [71 rows x 16 columns]

# %%
# Find competitor hosptitals with the largest number of total referrals.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    WITH vandy_address AS (
        SELECT *
        FROM npidata
        WHERE provider_org_name LIKE '%VANDERBILT%'
        GROUP BY provider_business_address_1
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
    )
    SELECT *
    FROM npidata
    --JOIN vandy_address AS va USING(npi)
    WHERE provider_org_name NOT LIKE '%VANDERBILT%'
    AND provider_business_address_1 IN (SELECT provider_business_address_1 FROM vandy_address)
    AND provider_business_city IN (SELECT provider_business_city FROM vandy_address)
    AND provider_business_zip5 IN (SELECT provider_business_zip5 FROM vandy_address)
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#            npi entity_type_code  \
# 0   1750387635                2
# 1   1568456986                2
# 2   1134116510                2
# 3   1427039858                2
# 4   1790761492                2
# ..         ...              ...
# 71  1770002263                2
# 72  1952820433                2
# 73  1619496197                2
# 74  1699294173                2
# 75  1629620638                2
#
#                                     provider_org_name provider_last_name  \
# 0   TENNESSEE ADVANCED NEURODIAGNOSTIC INSTITUTE, ...               None
# 1                   TENNESSEE ORTHOPAEDIC ALLIANCE PA               None
# 2              ARTHRITIS SPECIALISTS OF NASHVILLE INC               None
# 3                                 NES TENNESSEE, INC.               None
# 4                      METRO MEDICAL SKYLINE PHARMACY               None
# ..                                                ...                ...
# 71                   SHELBYVILLE HOSPITAL COMPANY LLC               None
# 72                   SHELBYVILLE HOSPITAL COMPANY LLC               None
# 73                   SHELBYVILLE HOSPITAL COMPANY LLC               None
# 74                   SHELBYVILLE HOSPITAL COMPANY LLC               None
# 75                    BABY & COMPANY NASHVILLE 1 PLLC               None
#
#    provider_first_name provider_middle_name provider_name_prefix  \
# 0                 None                 None                 None
# 1                 None                 None                 None
# 2                 None                 None                 None
# 3                 None                 None                 None
# 4                 None                 None                 None
# ..                 ...                  ...                  ...
# 71                None                 None                 None
# 72                None                 None                 None
# 73                None                 None                 None
# 74                None                 None                 None
# 75                None                 None                 None
#
#    provider_name_suffix provider_credential provider_business_address_1  \
# 0                  None                None             4525 HARDING RD
# 1                  None                None         3443 DICKERSON PIKE
# 2                  None                None         3443 DICKERSON PIKE
# 3                  None                None          2835 HIGHWAY 231 N
# 4                  None                None         3443 DICKERSON PIKE
# ..                  ...                 ...                         ...
# 71                 None                None        1612 N MAIN ST STE A
# 72                 None                None             1401 MADISON ST
# 73                 None                None        1612 N MAIN ST STE B
# 74                 None                None          3335 HIGHWAY 41A N
# 75                 None                None      3212 W END AVE STE 100
#
#    provider_business_address_2 provider_business_city provider_business_state  \
# 0                      STE 102              NASHVILLE                      TN
# 1                    SUITE 480              NASHVILLE                      TN
# 2                    SUITE 520              NASHVILLE                      TN
# 3                         None            SHELBYVILLE                      TN
# 4                    SUITE 110              NASHVILLE                      TN
# ..                         ...                    ...                     ...
# 71                        None            SHELBYVILLE                      TN
# 72                        None            SHELBYVILLE                      TN
# 73                        None            SHELBYVILLE                      TN
# 74                        None             UNIONVILLE                      TN
# 75                        None              NASHVILLE                      TN
#
#    provider_business_zip taxonomy_code provider_business_zip5
# 0              372052145    261QM1200X                  37205
# 1              372072519    207X00000X                  37207
# 2              372072519    207RR0500X                  37207
# 3              371607327    207P00000X                  37160
# 4              372072519    183500000X                  37207
# ..                   ...           ...                    ...
# 71             371602392    207Q00000X                  37160
# 72             371603629    207Q00000X                  37160
# 73             371602392    207Q00000X                  37160
# 74             371805033    207Q00000X                  37180
# 75             372035829    261QB0400X                  37203
#
# [76 rows x 16 columns]

# %%
# Find competitor hosptitals with the largest number of total referrals by from_npi
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
   SELECT SUM(ht.transaction_count) AS total_referrals
        , t.npi
        , t.provider_org_name
        , f.npi
    FROM filtered_hop_teaming AS ht
    JOIN npidata AS t
    ON ht.to_npi = t.npi
    JOIN npidata AS f
    ON ht.from_npi = f.npi
    GROUP BY t.npi, t.provider_org_name, f.npi
    HAVING t.provider_org_name NOT LIKE '%VANDERBILT%'
    ORDER BY total_referrals DESC
    LIMIT 10;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: no such column: classification
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-24-bfc1bcc57c41> in <module>
#      18     """
#      19
# ---> 20     test = pd.read_sql(query, db)
#      21
#      22 test
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     404
#     405     if isinstance(pandas_sql, SQLiteDatabase):
# --> 406         return pandas_sql.read_query(
#     407             sql,
#     408             index_col=index_col,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1631
#    1632         args = _convert_params(sql, params)
# -> 1633         cursor = self.execute(*args)
#    1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql '
#    SELECT SUM(ht.transaction_count) AS total_referrals
#         , t.npi
#         , t.provider_org_name
#         , f.npi
#         , classification
#     FROM filtered_hop_teaming AS ht
#     JOIN npidata AS t
#     ON ht.to_npi = t.npi
#     JOIN npidata AS f
#     ON ht.from_npi = f.npi
#     GROUP BY t.npi, t.provider_org_name, f.npi
#     HAVING t.provider_org_name NOT LIKE '%VANDERBILT%'
#     ORDER BY total_referrals DESC
#     LIMIT 10;
#     ': no such column: classification

# %%
# TESTING SQUARE
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM npidata
    LIMIT 1;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#           npi entity_type_code provider_org_name provider_last_name  \
# 0  1134122187                1              None           RUDNICKE
#
#   provider_first_name provider_middle_name provider_name_prefix  \
# 0              CHERYL               DENISE                 MRS.
#
#   provider_name_suffix provider_credential provider_business_address_1  \
# 0                 None                CRNP              250 25TH AVE N
#
#   provider_business_address_2 provider_business_city provider_business_state  \
# 0                     STE 412              NASHVILLE                      TN
#
#   provider_business_zip taxonomy_code provider_business_zip5
# 0             372031632    363L00000X                  37203

# %%
# TESTING SQUARE
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM npidata
    LIMIT 1;
    """ 
    
    test = pd.read_sql(query, db)

test

# %%
# Tingting's code for exporting to Neo4j

nodes = list(set(ht.from_npi.tolist() + ht.to_npi.tolist()))
node_df = pd.DataFrame({'npi:ID': nodes})
node_df[':LABEL'] = "Provider"
node_df.to_csv('import/nodes.csv', index = False)
edges = pd.DataFrame({':START_ID' : ht.from_npi, 'patient_count': ht.patient_count, 
                      'transaction_count': ht.transaction_count, 
                     ':END_ID' : ht.to_npi})
edges[':TYPE'] = 'REFERRED_TO'
edges.to_csv('import/edges.csv', index = False)

# %%
# Test to confirm the tables loaded.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT *
    FROM taxonomy
    LIMIT 1;
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#   taxonomy_code grouping   classification specialization
# 0    193200000X    Group  Multi-Specialty           None

# %%
# Test to confirm the tables loaded.
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
    SELECT DISTINCT classification
    FROM taxonomy
    """ 
    
    test = pd.read_sql(query, db)

test
# Out:
#                       classification
# 0                    Multi-Specialty
# 1                   Single Specialty
# 2               Allergy & Immunology
# 3                     Anesthesiology
# 4              Clinical Pharmacology
# ..                               ...
# 239  Secured Medical Transport (VAN)
# 240                             Taxi
# 241                            Train
# 242            Transportation Broker
# 243   Transportation Network Company
#
# [244 rows x 1 columns]
