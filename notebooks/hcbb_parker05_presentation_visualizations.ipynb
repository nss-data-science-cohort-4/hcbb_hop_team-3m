# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm
import plotly.express as px
import numpy as np
import plotly.graph_objects as go
import chart_studio
import chart_studio.plotly as py

# %%
pd.set_option("display.max_columns", 500)

# %%
file = open("../../plotly_api_key.txt")

api_key = file.read().replace("\n", " ")
file.close()

# %%
username = 'matttparker'

# %%
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %% [markdown]
# ## Create Visual of NPIs to Poach - NOT IN PRESENTATION

# %%
# From below, summarize by Facility Group
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE to_facility_group <> 'Vanderbilt University Medical Center'
            AND from_npi_specialty NOT IN ('Radiology', 'Emergency Medicine', 'Orthopaedic Surgery',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi
            HAVING to_groups = 1 AND npi_transactions >= 500
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group AS Facility_Group
            , npi
            , provider_first_name || ' ' || provider_last_name AS Name
            , classification AS Classification
            , COALESCE(specialization, 'None') AS Specialization
            , npi_transactions AS NPI_Transactions
            , npi_patients AS NPI_Patients
            , provider_business_address_1
            , provider_business_address_2
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
        FROM CTE_2
        ORDER BY to_facility_group
        """ 

    poach = pd.read_sql(query, db)

display(poach)
# Out:
#                 Facility_Group         npi              Name  \
# 0       Ascension Saint Thomas  1770519704      DAVID GIBSON
# 1       Ascension Saint Thomas  1720241185  WARREN STRIBLING
# 2       Ascension Saint Thomas  1598719536       DON CHOMSKY
# 3       Ascension Saint Thomas  1457317257        GUY MIOTON
# 4       Ascension Saint Thomas  1942429816     ANDREW ZURICK
# ..                         ...         ...               ...
# 279  Williamson Medical Center  1346397130       PAUL FLESER
# 280  Williamson Medical Center  1952771941   JAYANTHI SAMUEL
# 281  Williamson Medical Center  1033246640     OUIDA COLLINS
# 282  Williamson Medical Center  1063864775        PAULA DUNN
# 283  Williamson Medical Center  1497721526       JOHN HASSAN
#
#          Classification                                    Specialization  \
# 0     Internal Medicine                            Cardiovascular Disease
# 1     Internal Medicine  Advanced Heart Failure and Transplant Cardiology
# 2     Internal Medicine                            Cardiovascular Disease
# 3     Internal Medicine                            Cardiovascular Disease
# 4     Internal Medicine                            Cardiovascular Disease
# ..                  ...                                               ...
# 279             Surgery                                  Vascular Surgery
# 280  Nurse Practitioner                                            Family
# 281     Family Medicine                                              None
# 282     Family Medicine                                              None
# 283             Urology                                              None
#
#      NPI_Transactions  NPI_Patients provider_business_address_1  \
# 0                1648          1454             4230 HARDING RD
# 1                1648           711            4230 HARDING RD.
# 2                1621           701             4230 HARDING RD
# 3                1458          1155    1840 MEDICAL CENTER PKWY
# 4                1421          1265            4230 HARDING RD.
# ..                ...           ...                         ...
# 279               570           330                100 COVEY DR
# 280               519           467         4323 CAROTHERS PKWY
# 281               510           407                    3601 TVC
# 282               504           237             4091 MALLORY LN
# 283               503           348           1909 MALLORY LANE
#
#     provider_business_address_2 provider_business_city  \
# 0                     SUITE 330              NASHVILLE
# 1                      STE. 330              NASHVILLE
# 2                     SUITE 330              NASHVILLE
# 3                     SUITE 201           MURFREESBORO
# 4                     SUITE 330              NASHVILLE
# ..                          ...                    ...
# 279                   SUITE 204               FRANKLIN
# 280                   SUITE 205               FRANKLIN
# 281                        None              NASHVILLE
# 282                        None               FRANKLIN
# 283                   SUITE 110               FRANKLIN
#
#     provider_business_state provider_business_zip5
# 0                        TN                  37205
# 1                        TN                  37205
# 2                        TN                  37205
# 3                        TN                  37129
# 4                        TN                  37205
# ..                      ...                    ...
# 279                      TN                  37067
# 280                      TN                  37067
# 281                      TN                  37232
# 282                      TN                  37067
# 283                      TN                  37067
#
# [284 rows x 12 columns]

# %%
fig = px.treemap(poach, path=['Facility_Group', 'Classification', 'Name'], values='NPI_Patients',
                color='NPI_Transactions', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
fig.show()
#fig.write_html("/Users/mattparker/Documents/nss_projects/hcbb_hop_team-3m/notebooks/poaching_plotly.html")
py.plot(fig, filename = 'poaching_plotly_published', auto_open=True)
# Out:
# <div>                            <div id="b206f519-807f-47c7-b55e-9a871ed8fcb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b206f519-807f-47c7-b55e-9a871ed8fcb4")) {                    Plotly.newPlot(                        "b206f519-807f-47c7-b55e-9a871ed8fcb4",                        [{"branchvalues": "total", "customdata": [["AARON MILSTONE", "Internal Medicine", "Pulmonary Disease", "4323 CAROTHERS PKWY", "SUITE 605", "FRANKLIN", "TN", "37067", 1116.0], ["AARON PORTER", "Ophthalmology", "None", "3252 ASPEN GROVE DRIVE", "SUITE 1", "FRANKLIN", "TN", "37067", 653.0], ["ABU FAKHRUDDIN", "Internal Medicine", "Gastroenterology", "330 23RD AVE N", "SUITE 300", "NASHVILLE", "TN", "37203", 729.0], ["ADAM PRUDOFF", "Internal Medicine", "Cardiovascular Disease", "3601 TVC", null, "NASHVILLE", "TN", "37232", 1652.0], ["AHMAD ABU-HALIMAH", "Internal Medicine", "Cardiovascular Disease", "VANDERBILT UNIVERSITY MEDICAL CTR. CARDIOLOGY DIVISION.", "383 PRB, 2220 PIERCE AVE.", "NASHVILLE", "TN", "37232", 658.0], ["ALBERTO GONZALEZ-BERNAL", "Internal Medicine", "Critical Care Medicine", "3443 DICKERSON PK", "SUITE 680", "NASHVILLE", "TN", "37207", 914.0], ["AMANDA DANIEL", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 605.0], ["AMIT CHOKSI", "Internal Medicine", "Gastroenterology", "1222 TROTWOOD AVENUE", "STE 501", "COLUMBIA", "TN", "38401", 1657.0], ["AMIT KESWANI", "Internal Medicine", "Cardiovascular Disease", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 944.0], ["AMIT SINGH", "Internal Medicine", "None", "300 STONECREST BLVD STE 110", null, "SMYRNA", "TN", "37167", 1164.0], ["ANDREA BECK", "Internal Medicine", "None", "2400 PATTERSON ST", "SUITE 400", "NASHVILLE", "TN", "37203", 628.0], ["ANDREW GOODMAN", "Internal Medicine", "Interventional Cardiology", "2400 PATTERSON ST STE 502", null, "NASHVILLE", "TN", "37203", 687.0], ["ANDREW MCRAE", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 1278.0], ["ANDREW MCVIE", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 872.0], ["ANDREW SAGER", "Internal Medicine", "Cardiovascular Disease", "222 22ND AVE N", "STE 400", "NASHVILLE", "TN", "37203", 563.0], ["ANDREW ZURICK", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD.", "SUITE 330", "NASHVILLE", "TN", "37205", 1421.0], ["ANGELO CANONICO", "Internal Medicine", "Pulmonary Disease", "4230 HARDING RD", "SUITE 400", "NASHVILLE", "TN", "37205", 1041.0], ["ANNIS MARNEY", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 654.0], ["ANSEL ANDERSON", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 901.0], ["ANTHONY KHIM", "Specialist", "None", "101 BERRYWOOD DR", null, "COLUMBIA", "TN", "38401", 1090.0], ["ARNEL PANELO", "Hospitalist", "None", "2400 PATTERSON ST", "SUITE 311", "NASHVILLE", "TN", "37203", 513.0], ["ARTHUR CONSTANTINE", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING PIKE", "SUITE 330", "NASHVILLE", "TN", "37205", 745.0], ["ASHLEY ROSE", "Internal Medicine", "None", "2300 PATTERSON ST", null, "NASHVILLE", "TN", "37203", 530.0], ["BARRETT CONNER", "Internal Medicine", "Pulmonary Disease", "3443 DICKERSON PIKE", "SUITE 680", "NASHVILLE", "TN", "37207", 904.0], ["BELINDA BART", "Family Medicine", "None", "1605 NASHVILLE HWY", "SUITE 200", "COLUMBIA", "TN", "38401", 995.0], ["BEN GARDNER", "Internal Medicine", "None", "854 W JAMES CAMPBELL BLVD", "SUITE 403", "COLUMBIA", "TN", "38401", 1182.0], ["BENJAMIN DEHNER", "Urology", "None", "4230 HARDING RD", "SUITE 521", "NASHVILLE", " ...
# 'https://plotly.com/~matttparker/1/'

# %% [markdown]
# # Percent Competition: Question 2/3 Visualization

# %%
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH vandy_selector AS (
            SELECT from_npi, patient_count, CASE
                WHEN to_facility_group = 'Vanderbilt University Medical Center' THEN 'vandy'
                ELSE 'not_vandy' END AS to_vandy,
                SUM(patient_count) OVER(PARTITION BY from_npi) AS total_patients
            FROM referrals
        ), percents AS (
            SELECT from_npi AS npi
                , patient_count AS non_vandy_patients
                , total_patients
                , ROUND(100.0 * patient_count/total_patients, 2) AS pct_competition
            FROM vandy_selector
            WHERE to_vandy = 'not_vandy'
            GROUP BY from_npi, to_vandy
        ), npi_details AS (
            SELECT npi
                , provider_first_name || ' ' || provider_last_name AS Name
                , classification AS Classification
                , COALESCE(specialization, 'None') AS Specialization
                , provider_business_address_1
                , provider_business_address_2
                , provider_business_city
                , provider_business_state
                , provider_business_zip5
            FROM npidata_nashville
            GROUP BY npi
        )
        SELECT *
        FROM percents
        JOIN npi_details USING(npi)
        WHERE classification NOT IN ('Emergency Medicine', 'Orthopaedic Surgery', --'Radiology',
                                            'Pathology', 'Anesthesiology')
        AND total_patients >= 500
        """ 

    percents_treemap = pd.read_sql(query, db)

display(percents_treemap)
# Out:
#             npi  non_vandy_patients  total_patients  pct_competition  \
# 0    1003819277                  91             675            13.48
# 1    1003862566                1110            2738            40.54
# 2    1013179860                  71            1241             5.72
# 3    1013184340                1781            2257            78.91
# 4    1013908730                 462             548            84.31
# ..          ...                 ...             ...              ...
# 441  1972658060                1770            1878            94.25
# 442  1982661617                  96             680            14.12
# 443  1982796306                 247             752            32.85
# 444  1992064935                  82             686            11.95
# 445  1992960298                 682            2043            33.38
#
#                 Name     Classification             Specialization  \
# 0          JOHN CAGE  Internal Medicine     Cardiovascular Disease
# 1         MARC SOBLE          Radiology       Diagnostic Radiology
# 2          GARY YAWN  Internal Medicine  Interventional Cardiology
# 3       MELINDA SAVA          Radiology       Diagnostic Radiology
# 4      JOSEPH PARKER  Internal Medicine           Gastroenterology
# ..               ...                ...                        ...
# 441      TERRY KETCH  Internal Medicine     Cardiovascular Disease
# 442   CHRISTIE GREEN  Internal Medicine                 Nephrology
# 443   MATTHEW ABBATE  Internal Medicine                       None
# 444   MENGISTU BERIE  Internal Medicine                       None
# 445  GABRIEL STARACE          Radiology       Diagnostic Radiology
#
#             provider_business_address_1 provider_business_address_2  \
# 0                        222 22ND AVE N                     STE 400
# 1                3024 BUSINESS PARK CIR                        None
# 2    353 NEW SHACKLE ISLAND RD STE 300C                        None
# 3                3024 BUSINESS PARK CIR                        None
# 4                        222 22ND AVE N                        None
# ..                                  ...                         ...
# 441         3443 DICKERSON PIKE STE 430                        None
# 442                    1617 WILLIAMS DR                    STE. 200
# 443                            3601 TVC                        None
# 444         1005 DR. D.B.TODD JR. BLVD.                        None
# 445              3024 BUSINESS PARK CIR                        None
#
#     provider_business_city provider_business_state provider_business_zip5
# 0                NASHVILLE                      TN                  37203
# 1           GOODLETTSVILLE                      TN                  37072
# 2           HENDERSONVILLE                      TN                  37075
# 3           GOODLETTSVILLE                      TN                  37072
# 4                NASHVILLE                      TN                  37203
# ..                     ...                     ...                    ...
# 441              NASHVILLE                      TN                  37207
# 442           MURFREESBORO                      TN                  37129
# 443              NASHVILLE                      TN                  37232
# 444               NASHVILE                      TN                  37208
# 445         GOODLETTSVILLE                      TN                  37072
#
# [446 rows x 12 columns]

# %%
percent_competition = px.treemap(percents_treemap, path=['Classification', 'Specialization', 'Name'], values='non_vandy_patients',
                color='pct_competition', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5', 'total_patients'],
                color_continuous_scale='Emrld')
percent_competition.show()
#percent_competition.write_html("/Users/mattparker/Documents/nss_projects/hcbb_hop_team-3m/notebooks/percent_competition_radiology.html")
percent_competition.plot(fig, filename = 'percent_competition_radiology', auto_open=True)
# Out:
# <div>                            <div id="8fe3c948-31ee-4063-940f-39d7dcacce5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8
"Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD.", "SUITE 330", "NASHVILLE", "TN", "37205", 1265, 87.91], ["ANGELO CANONICO", "Internal Medicine", "Pulmonary Disease", "4230 HARDING RD", "SUITE 400", "NASHVILLE", "TN", "37205", 861, 100.0], ["ANIL NACHNANI", "Internal Medicine", "None", "300 STEAM PLANT RD.", "STE 300", "GALLATIN", "TN", "37066", 546, 15.2], ["ANJALI KHURANA", "Radiology", "Diagnostic Radiology", "210 25TH AVE N STE 602", null, "NASHVILLE", "TN", "37203", 1275, 34.67], ["ANN OWEN", "Radiology", "Diagnostic Radiology", "212 HERITAGE PARK DR", null, "MURFREESBORO", "TN", "37129", 1640, 95.55], ["ANSEL ANDERSON", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 834, 100.0], ["ANTHONY KHIM", "Specialist", "None", "101 BERRYWOOD DR", null, "COLUMBIA", "TN", "38401", 649, 100.0], ["ANUMEET PRIYADARSHI", "Internal Medicine", "Nephrology", "270 EAST MAIN STREET", "SUITE 200", "GALLATIN", "TN", "37066", 665, 15.04], ["ARTHUR CONSTANTINE", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING PIKE", "SUITE 330", "NASHVILLE", "TN", "37205" ...

# %% [markdown]
# # Alvin Request #1 (Alternate to Previous Visual) - NOT IN PRESENTATION

# %%
fig_1 = px.treemap(poach, path=['Classification', 'Specialization', 'Name'], values='NPI_Patients',
                color='NPI_Patients', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
fig_1.show()
# Out:
# <div>                            <div id="0452165f-30ae-470f-94a0-95067450d9fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0452165f-30ae-470f-94a0-95067450d9fb")) {                    Plotly.newPlot(                        "0452165f-30ae-470f-94a0-95067450d9fb",                        [{"branchvalues": "total", "customdata": [["AARON MILSTONE", "Internal Medicine", "Pulmonary Disease", "4323 CAROTHERS PKWY", "SUITE 605", "FRANKLIN", "TN", "37067", 665.0], ["AARON PORTER", "Ophthalmology", "None", "3252 ASPEN GROVE DRIVE", "SUITE 1", "FRANKLIN", "TN", "37067", 379.0], ["ABU FAKHRUDDIN", "Internal Medicine", "Gastroenterology", "330 23RD AVE N", "SUITE 300", "NASHVILLE", "TN", "37203", 573.0], ["ADAM PRUDOFF", "Internal Medicine", "Cardiovascular Disease", "3601 TVC", null, "NASHVILLE", "TN", "37232", 1208.0], ["AHMAD ABU-HALIMAH", "Internal Medicine", "Cardiovascular Disease", "VANDERBILT UNIVERSITY MEDICAL CTR. CARDIOLOGY DIVISION.", "383 PRB, 2220 PIERCE AVE.", "NASHVILLE", "TN", "37232", 487.0], ["ALBERTO GONZALEZ-BERNAL", "Internal Medicine", "Critical Care Medicine", "3443 DICKERSON PK", "SUITE 680", "NASHVILLE", "TN", "37207", 759.0], ["AMANDA DANIEL", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 283.0], ["AMIT CHOKSI", "Internal Medicine", "Gastroenterology", "1222 TROTWOOD AVENUE", "STE 501", "COLUMBIA", "TN", "38401", 1271.0], ["AMIT KESWANI", "Internal Medicine", "Cardiovascular Disease", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 722.0], ["AMIT SINGH", "Internal Medicine", "None", "300 STONECREST BLVD STE 110", null, "SMYRNA", "TN", "37167", 651.0], ["ANDREA BECK", "Internal Medicine", "None", "2400 PATTERSON ST", "SUITE 400", "NASHVILLE", "TN", "37203", 252.0], ["ANDREW GOODMAN", "Internal Medicine", "Interventional Cardiology", "2400 PATTERSON ST STE 502", null, "NASHVILLE", "TN", "37203", 396.0], ["ANDREW MCRAE", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 813.0], ["ANDREW MCVIE", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 795.0], ["ANDREW SAGER", "Internal Medicine", "Cardiovascular Disease", "222 22ND AVE N", "STE 400", "NASHVILLE", "TN", "37203", 468.0], ["ANDREW ZURICK", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD.", "SUITE 330", "NASHVILLE", "TN", "37205", 1265.0], ["ANGELO CANONICO", "Internal Medicine", "Pulmonary Disease", "4230 HARDING RD", "SUITE 400", "NASHVILLE", "TN", "37205", 861.0], ["ANNIS MARNEY", "Internal Medicine", "Endocrinology, Diabetes & Metabolism", "330 23RD AVE N", "SUITE 500", "NASHVILLE", "TN", "37203", 373.0], ["ANSEL ANDERSON", "Specialist", "None", "4220 HARDING RD", null, "NASHVILLE", "TN", "37205", 834.0], ["ANTHONY KHIM", "Specialist", "None", "101 BERRYWOOD DR", null, "COLUMBIA", "TN", "38401", 649.0], ["ARNEL PANELO", "Hospitalist", "None", "2400 PATTERSON ST", "SUITE 311", "NASHVILLE", "TN", "37203", 410.0], ["ARTHUR CONSTANTINE", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING PIKE", "SUITE 330", "NASHVILLE", "TN", "37205", 628.0], ["ASHLEY ROSE", "Internal Medicine", "None", "2300 PATTERSON ST", null, "NASHVILLE", "TN", "37203", 369.0], ["BARRETT CONNER", "Internal Medicine", "Pulmonary Disease", "3443 DICKERSON PIKE", "SUITE 680", "NASHVILLE", "TN", "37207", 650.0], ["BELINDA BART", "Family Medicine", "None", "1605 NASHVILLE HWY", "SUITE 200", "COLUMBIA", "TN", "38401", 596.0], ["BEN GARDNER", "Internal Medicine", "None", "854 W JAMES CAMPBELL BLVD", "SUITE 403", "COLUMBIA", "TN", "38401", 681.0], ["BENJAMIN DEHNER", "Urology", "None", "4230 HARDING RD", "SUITE 521", "NASHVILLE", "TN", " ...

# %% [markdown]
# # Hospital to Specialty

# %%
# From below, summarize by Facility Group
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE from_npi_specialty NOT IN ('Emergency Medicine', 'Orthopaedic Surgery', --'Radiology',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group AS Facility_Group
            , npi
            , provider_first_name || ' ' || provider_last_name AS Name
            , classification AS Classification
            , COALESCE(specialization, 'None') AS Specialization
            , npi_transactions AS NPI_Transactions
            , npi_patients AS NPI_Patients
            , provider_business_address_1
            , provider_business_address_2
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
            , SUM(NPI_Patients) AS Total_Patients
        FROM CTE_2
        GROUP BY to_facility_group, classification, specialization
        """ 

    poach2 = pd.read_sql(query, db)

display(poach2)
# Out:
#                 Facility_Group         npi               Name  \
# 0       Ascension Saint Thomas  1497709752      ERIKA GILBERT
# 1       Ascension Saint Thomas  1487780268       NORMA KRANTZ
# 2       Ascension Saint Thomas  1952561474   SREE SURYADEVARA
# 3       Ascension Saint Thomas  1952304966        JOHN SALYER
# 4       Ascension Saint Thomas  1386878957  HOLLY BLANKENSHIP
# ..                         ...         ...                ...
# 452  Williamson Medical Center  1538157219       LAURA BASKIN
# 453  Williamson Medical Center  1174622500        MARK KELLEY
# 454  Williamson Medical Center  1750327052       CARY PULLIAM
# 455  Williamson Medical Center  1184657272     ERIC LAMBRIGHT
# 456  Williamson Medical Center  1750382727         JOEL LOCKE
#
#                                         Classification     Specialization  \
# 0                           Anesthesiologist Assistant               None
# 1                            Clinical Nurse Specialist     Women's Health
# 2                               Colon & Rectal Surgery               None
# 3                                      Family Medicine               None
# 4                                      Family Medicine     Adult Medicine
# ..                                                 ...                ...
# 452                                            Surgery               None
# 453                                            Surgery  Surgical Oncology
# 454                                            Surgery   Vascular Surgery
# 455  Thoracic Surgery (Cardiothoracic Vascular Surg...               None
# 456                                            Urology               None
#
#      NPI_Transactions  NPI_Patients provider_business_address_1  \
# 0                  87            84    1800 MEDICAL CENTER PKWY
# 1                 146           141      300 20TH AVE N STE 401
# 2                 129            98              2011 CHURCH ST
# 3                 904           604       127 CRESTVIEW PARK DR
# 4                 105            75      370 DOOLITTLE RD STE 1
# ..                ...           ...                         ...
# 452               266           143            1272 GARRISON DR
# 453               509           300  3601 THE VANDERBILT CLINIC
# 454               691           385         4601 CAROTHERS PKWY
# 455               492           258      3601 VANDERBILT CLINIC
# 456               747           488         4601 CAROTHERS PKWY
#
#     provider_business_address_2 provider_business_city  \
# 0                     SUITE 330           MURFREESBORO
# 1                          None              NASHVILLE
# 2                      STE. 703              NASHVILLE
# 3                          None                DICKSON
# 4                          None               WOODBURY
# ..                          ...                    ...
# 452                        None           MURFREESBORO
# 453                        None              NASHVILLE
# 454                     STE 375               FRANKLIN
# 455                        None              NASHVILLE
# 456                   SUITE 475               FRANKLIN
#
#     provider_business_state provider_business_zip5  Total_Patients
# 0                        TN                  37129              84
# 1                        TN                  37203             141
# 2                        TN                  37203             226
# 3                        TN                  37055            6116
# 4                        TN                  37190              75
# ..                      ...                    ...             ...
# 452                      TN                  37129             913
# 453                      TN                  37232             300
# 454                      TN                  37067             949
# 455                      TN                  37232             258
# 456                      TN                  37067            1272
#
# [457 rows x 13 columns]

# %%
hospital_to_specialty = px.treemap(poach2, path=['Facility_Group', 'Classification', 'Specialization'], values='Total_Patients',
                color='Total_Patients', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
hospital_to_specialty.show()
hospital_to_specialty.write_html("/Users/mattparker/Documents/nss_projects/hcbb_hop_team-3m/notebooks/hospital_to_specialty_radiology.html")
# Out:
# <div>                            <div id="675e19a9-b651-4a78-bbff-2b88f0bdaa39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
se Practitioner", "Adult Health", "3601 THE VANDERBILT CLINIC", null, "NASHVILLE", "TN", "37232", 600.0], ["HOLLY BLANKENSHIP", "Family Medicine", "Adult Medicine", "370 DOOLITTLE RD STE 1", null, "WOODBURY", "TN", "37190", 75.0], ["MICHAEL KELLOGG", "Family Medicine", "Adult Medicine", "353 NEW SHACKLE ISLAND RD", "SUITE 122B", "HENDERSONVILLE", "TN", "37075", 194.0], ["YEKOLLA REDDY", "Family Medicine", "Adult Medicine", "3400 LEBANON RD", null, "MURFREESBORO", "TN", "37129", 335.0], ["WARREN STRIBLING", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "4230 HARDING RD.", "STE. 330", "NASHVILLE", "TN", "37205", 3344.0], ["THOMAS JOHNSTON", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "2400 PATTERSON ST", "SUITE 502", "NASHVILLE", "TN", "37203", 2032.0], ["DOUGLAS BRINKLEY", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "3601 THE VANDERBILT CLINIC", "VANDERBILT HEART & VASCULAR INSTITUTE", "NASHVILLE", "TN", "37232", 2092 ...

# %% [markdown]
# # Alvin Request #3

# %%
# From below, summarize by Facility Group
# Find hospital groups with the largest number of single group, non-Vanderbilt NPIs
# Remove Radiology
with sqlite3.connect('../data/hcbb.sqlite') as db :
    query = """
        WITH CTE AS (
            SELECT from_npi
                , COUNT(DISTINCT to_facility_group) AS to_groups
                , SUM(transaction_count) AS npi_transactions
                , SUM(patient_count) AS npi_patients
                , to_facility_group
            FROM referrals
            WHERE from_npi_specialty NOT IN ('Emergency Medicine', 'Orthopaedic Surgery', --'Radiology',
                                            'Pathology', 'Anesthesiology')
            GROUP BY from_npi
        ), CTE_2 AS(
            SELECT CTE.to_facility_group, CTE.npi_transactions, CTE.npi_patients, n.*
            FROM CTE
            INNER JOIN npidata_nashville AS n 
                ON CTE.from_npi = n.npi
            ORDER BY CTE.npi_transactions DESC
        )
        SELECT to_facility_group AS Facility_Group
            , npi
            , provider_first_name || ' ' || provider_last_name AS Name
            , classification AS Classification
            , COALESCE(specialization, 'None') AS Specialization
            , npi_transactions AS NPI_Transactions
            , npi_patients AS NPI_Patients
            , provider_business_address_1
            , provider_business_address_2
            , provider_business_city
            , provider_business_state
            , provider_business_zip5
            , SUM(NPI_Patients) AS Total_Patients
        FROM CTE_2
        GROUP BY classification, specialization, to_facility_group
        """ 

    poach3 = pd.read_sql(query, db)

display(poach3)
# Out:
#                            Facility_Group         npi             Name  \
# 0                                     HCA  1780731661     ROBERT VALET
# 1           Maury Regional Medical Center  1558310367     JOHN NORVELL
# 2    Vanderbilt University Medical Center  1518041623  RYSZARD DWORSKI
# 3               Williamson Medical Center  1649226770  HAROLD MOESSNER
# 4    Vanderbilt University Medical Center  1184617441     KENNETH BABE
# ..                                    ...         ...              ...
# 452         Maury Regional Medical Center  1710955034   JAMES MARSHALL
# 453            Nashville General Hosptial  1609052554     KELVIN MOSES
# 454  Vanderbilt University Medical Center  1922107358        SAM CHANG
# 455             Williamson Medical Center  1750382727       JOEL LOCKE
# 456                                   HCA  1952388977       MARCY ABEL
#
#            Classification                                     Specialization  \
# 0    Allergy & Immunology                                               None
# 1    Allergy & Immunology                                               None
# 2    Allergy & Immunology                                               None
# 3    Allergy & Immunology                                               None
# 4    Allergy & Immunology                                            Allergy
# ..                    ...                                                ...
# 452               Urology                                               None
# 453               Urology                                               None
# 454               Urology                                               None
# 455               Urology                                               None
# 456               Urology  Female Pelvic Medicine and Reconstructive Surgery
#
#      NPI_Transactions  NPI_Patients provider_business_address_1  \
# 0                 369           345           4230 HARDING PIKE
# 1                 156            88            400 SUGARTREE LN
# 2                 413           289                    3601 TVC
# 3                 169            79             1909 MALLORY LN
# 4                 343           220  3601 THE VANDERBILT CLINIC
# ..                ...           ...                         ...
# 452              1051           600           1222 TROTWOOD AVE
# 453               374           152  3601 THE VANDERBILT CLINIC
# 454              1441           733                    3601 TVC
# 455               747           488         4601 CAROTHERS PKWY
# 456               245           181          2801 CHARLOTTE AVE
#
#     provider_business_address_2 provider_business_city  \
# 0          EAST PLAZA SUITE 703              NASHVILLE
# 1                     SUITE 100               FRANKLIN
# 2                          None              NASHVILLE
# 3                     SUITE 308               FRANKLIN
# 4                          None              NASHVILLE
# ..                          ...                    ...
# 452                   SUITE 601               COLUMBIA
# 453                        None              NASHVILLE
# 454                        None              NASHVILLE
# 455                   SUITE 475               FRANKLIN
# 456                        None              NASHVILLE
#
#     provider_business_state provider_business_zip5  Total_Patients
# 0                        TN                  37205             627
# 1                        TN                  37064              88
# 2                        TN                  37232             335
# 3                        TN                  37067             151
# 4                        TN                  37232             343
# ..                      ...                    ...             ...
# 452                      TN                  38401            1216
# 453                      TN                  37232             152
# 454                      TN                  37232            4550
# 455                      TN                  37067            1272
# 456                      TN                  37209             181
#
# [457 rows x 13 columns]

# %%
classification_to_hospital = px.treemap(poach3, path=['Classification', 'Specialization', 'Facility_Group'], values='Total_Patients',
                color='Total_Patients', 
                hover_data=['Name', 'Classification', 'Specialization', 'provider_business_address_1',
                           'provider_business_address_2', 'provider_business_city',
                           'provider_business_state', 'provider_business_zip5'],
                color_continuous_scale='Emrld')
classification_to_hospital.show()
classification_to_hospital.write_html("/Users/mattparker/Documents/nss_projects/hcbb_hop_team-3m/notebooks/classification_to_hospital_radiology.html")
# Out:
# <div>                            <div id="43a1f7bf-a3c3-4ae0-85d7-8d7644642bd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43a1f7bf-a3c3-4ae0-85d7-8d7644642bd8")) {                    Plotly.newPlot(                        "43a1f7bf-a3c3-4ae0-85d7-8d7644642bd8",                        [{"branchvalues": "total", "customdata": [["FRANKLIN GRAUZER", "Nurse Practitioner", "Acute Care", "4230 HARDING RD", "SUITE 435", "NASHVILLE", "TN", "37205", 3979.0], ["JACY CUNNINGHAM", "Nurse Practitioner", "Adult Health", "783 OLD HICKORY BLVD STE 355", null, "BRENTWOOD", "TN", "37027", 1349.0], ["HOLLY BLANKENSHIP", "Family Medicine", "Adult Medicine", "370 DOOLITTLE RD STE 1", null, "WOODBURY", "TN", "37190", 75.0], ["WARREN STRIBLING", "Internal Medicine", "Advanced Heart Failure and Transplant Cardiology", "4230 HARDING RD.", "STE. 330", "NASHVILLE", "TN", "37205", 3344.0], ["WILSON KEMP", "Internal Medicine", "Cardiovascular Disease", "4230 HARDING RD", "SUITE 330", "NASHVILLE", "TN", "37205", 27448.0], ["WILLIAM THOMP